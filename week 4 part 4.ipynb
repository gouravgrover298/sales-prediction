# %% [markdown]
# <a href="https://colab.research.google.com/github/Tonyosa/sales-perdictions/blob/main/week%204%20part%204.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##* George Osadchenko*
# ## *Project 1 - Part 2 (Core)*  Week 2 part 2
# and Project 1 Part 3 / week 3
# and Project 1 week 4 part 4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# %%
df = pd.read_csv("/content/sample_data/sales_predictions (1).csv")
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# Getting info on data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# 1) How many rows and columns?

# %%
print(len(df.columns))
# Out:
# 12

# %%
print(len(df))
# Out:
# 8523

# %% [markdown]
# 2) What are the datatypes of each variable?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# 3) Are there duplicates? If so, drop any duplicates.

# %%
df2 = df.drop_duplicates().sum()
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# ...

# %% [markdown]
# 4) Identify missing values.

# %%
df.isna().any()
# Out:
# Item_Identifier              False
# Item_Weight                   True
# Item_Fat_Content             False
# Item_Visibility              False
# Item_Type                    False
# Item_MRP                     False
# Outlet_Identifier            False
# Outlet_Establishment_Year    False
# Outlet_Size                   True
# Outlet_Location_Type         False
# Outlet_Type                  False
# Item_Outlet_Sales            False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 3873

# %% [markdown]
# 5) Decide on how to address the missing values and do it! (This requires your judgement, so explain your choice).

# %%
df.dropna(inplace=True)

# %% [markdown]
# Here I chose to drop all of the missing values.

# %%
df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
print(df.isnull().sum().sum())
# Out:
# 0

# %% [markdown]
# 6) Confirm that there are no missing values after addressing them.

# %%
print(df.isnull().sum().sum())
# Out:
# 0

# %% [markdown]
# 7) Find and fix any inconsistent categories of data (example: fix cat, Cat, and cats so that they are consistent)

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    2774
# Regular    1575
# LF          177
# reg          71
# low fat      53
# Name: Item_Fat_Content, dtype: int64

# %%
df['Item_Fat_Content']= df['Item_Fat_Content'].replace('reg', 'Regular')
df['Item_Fat_Content']= df['Item_Fat_Content'].replace('LF', 'Low Fat')
df['Item_Fat_Content']= df['Item_Fat_Content'].replace('Reg', 'Regular')
df['Item_Fat_Content']= df['Item_Fat_Content'].replace('low fat', 'Low Fat')
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    3004
# Regular    1646
# Name: Item_Fat_Content, dtype: int64

# %% [markdown]
# 8) For any numerical columns, obtain the summary statistics of each (min, max, mean)

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 4     Household   53.8614            OUT013                       1987
# 5  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# ...

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  4650.000000      4650.000000  4650.000000                4650.000000
# mean     12.898675         0.060700   141.716328                1999.190538
# std       4.670973         0.044607    62.420534                   7.388800
# min       4.555000         0.000000    31.490000                1987.000000
# 25%       8.770000         0.025968    94.409400                1997.000000
# 50%      12.650000         0.049655   142.979900                1999.000000
# 75%      17.000000         0.088736   186.614150                2004.000000
# max      21.350000         0.188323   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        4650.000000
# mean         2272.037489
# std          1497.964740
# min            69.243200
# 25%          1125.202000
# 50%          1939.808300
# 75%          3111.616300
# max         10256.649000

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/sample_data/sales_predictions (1).csv")
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df['Item_MRP'].value_counts()
# Out:
# 172.0422    7
# 170.5422    6
# 196.5084    6
# 188.1872    6
# 142.0154    6
#            ..
# 97.3384     1
# 83.1934     1
# 96.6752     1
# 152.6682    1
# 75.4670     1
# Name: Item_MRP, Length: 5938, dtype: int64

# %%
ax = sns.scatterplot(data=df, x = 'Item_Weight', y = 'Item_Fat_Content', hue = 'Item_MRP')
ax.legend(bbox_to_anchor=[1,1]);

# %%
ax = sns.scatterplot(data=df, x = 'Item_Weight', y = 'Item_Fat_Content', hue = 'Item_MRP', palette = 'plasma')
ax.set_title('How education effects Item_Fat_Content')
ax.set_xlabel('Item_Weight')
ax.legend(bbox_to_anchor=[1,1]);
#ax.legend().remove()

# %%
sns.barplot(data=df, x='Item_Weight', y = 'Item_Fat_Content')

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.dropna(inplace = True)

# %%
sns.lineplot(data = df, x = 'Item_Visibility', y = 'Item_Type',ci = None, marker = 'o')

# %%
fig, axes = plt.subplots(nrows = 3, figsize = (20,12), sharex = True)

sns.lineplot(data = df, x = 'Item_Visibility', y = 'Item_Type', ci = None, marker = 'o', ax = axes[0])

sns.lineplot(data = df, x = 'Item_Visibility', y = 'Item_Weight', ci = None, marker = 'o', ax = axes[1])

sns.lineplot(data = df, x = 'Item_Visibility', y = 'Item_Outlet_Sales', ci = None, marker = 'o', ax = axes[2])

[ax.grid() for ax in axes];

fig.suptitle('Item_Weight and Outlet_Establishment_Year', fontsize = 20, fontweight = 'bold')
# Out:
# Text(0.5, 0.98, 'Item_Weight and Outlet_Establishment_Year')

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df['Item_Identifier'].describe()
# Out:
# count      8523
# unique     1559
# top       FDW13
# freq         10
# Name: Item_Identifier, dtype: object

# %%
df['Item_Visibility'].plot(kind ='box')
plt.title('Item_Identifier')
plt.ylabel('Item_Visibility');
##plt.show()

# %%
df['Item_Visibility'].value_counts
df.plot(kind ='bar', color = ['blue','red'])
plt.title('Item_Visibility:freq , top')
plt.show()

# %%
sns.histplot(data=df,x='Item_Weight')

# %%
sns.heatmap(df.corr(),annot=True,cmap='Blues');

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.groupby(['Item_Type'])['Item_Weight'].mean()
# Out:
# Item_Type
# Baking Goods             12.277108
# Breads                   11.346936
# Breakfast                12.768202
# Canned                   12.305705
# Dairy                    13.426069
# Frozen Foods             12.867061
# Fruits and Vegetables    13.224769
# Hard Drinks              11.400328
# Health and Hygiene       13.142314
# Household                13.384736
# Meat                     12.817344
# Others                   13.853285
# Seafood                  12.552843
# Snack Foods              12.987880
# Soft Drinks              11.847460
# Starchy Foods            13.690731
# Name: Item_Weight, dtype: float64

# %%
df= df.groupby(['Item_Type'])['Item_Weight'].nunique()

# %%
df
# Out:
# Item_Type
# Baking Goods              94
# Breads                    42
# Breakfast                 18
# Canned                    92
# Dairy                     95
# Frozen Foods             119
# Fruits and Vegetables    145
# Hard Drinks               36
# Health and Hygiene        78
# Household                122
# Meat                      69
# Others                    28
# Seafood                   10
# Snack Foods              139
# Soft Drinks               66
# Starchy Foods             28
# Name: Item_Weight, dtype: int64

# %%
df= np.array(df.index)
df
# Out:
# array(['Baking Goods', 'Breads', 'Breakfast', 'Canned', 'Dairy',
#        'Frozen Foods', 'Fruits and Vegetables', 'Hard Drinks',
#        'Health and Hygiene', 'Household', 'Meat', 'Others', 'Seafood',
#        'Snack Foods', 'Soft Drinks', 'Starchy Foods'], dtype=object)

# %%
plt.style.use('seaborn')

# %%
plt.plot(df, c= 'k')

# %%
plt.plot(df, c= 'k')
plt.xlim(left=2,right=2)
plt.ylim(bottom=0,top=18)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Attempting to set identical left == right == 2 results in singular transformations; automatically expanding.
# (0.0, 18.0)

# %%
plt.style.use('seaborn')

# %%
plt.plot(df, c= 'k')
plt.xlim(left=2,right=2)
plt.ylim(bottom=0,top=18)
plt.xlabel('Year', fontsize = 16)
plt.ylabel('Number of Olympians', fontsize = 16)
plt.title('Number of Olympians Over the Years', fontsize = 16)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Attempting to set identical left == right == 2 results in singular transformations; automatically expanding.
# Text(0.5, 1.0, 'Number of Olympians Over the Years')
